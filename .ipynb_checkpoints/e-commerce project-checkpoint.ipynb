# %%
import pandas as pd 
import plotly.express as px # plotly advanced than matplotlib and seaborn and is used for data visualization
import plotly.graph_objects as go #for advanced and customized graphs
import plotly.io as pio #for graph templates
import plotly.colors as colors #for colors
pio.templates.default = "plotly_white"

# %%
data=pd.read_csv("superstore_data.csv",encoding='latin-1')

# %%
data
# Out:
#       ï»¿Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0             1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1             2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2             3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3             4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4             5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# ...         ...             ...         ...         ...             ...
# 9989       9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990       9991  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9991       9992  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9992       9993  CA-2017-121258   2/26/2017  03-03-2017  Standard Class
# 9993       9994  CA-2017-119914  05-04-2017  05-09-2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
data.head() #for first 5 rows
# Out:
#    ï»¿Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 1          2  CA-2016-152156  11-08-2016  11-11-2016    Second Class
# 2          3  CA-2016-138688  06-12-2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10-11-2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10-11-2015  10/18/2015  Standard Class
#
#   Customer ID    Customer Name    Segment        Country             City  \
# 0    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1    CG-12520      Claire Gute   Consumer  United States        Henderson
# 2    DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#    ... Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data.describe() #for descriptive stats only for numericals
# Out:
#          ï»¿Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
data.info() #for more information
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ï»¿Row ID      9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     9994 non-null   str
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
# ...

# %% [markdown]
# # CONVERTING DATE COLUMNS

# %%
data['Order Date']=pd.to_datetime(data['Order Date'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ï»¿Row ID      9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     4042 non-null   datetime64[us]
#  3   Ship Date      9994 non-null   str
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
# ...

# %%
data['Ship Date']=pd.to_datetime(data['Ship Date'], errors='coerce')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ï»¿Row ID      9994 non-null   int64
#  1   Order ID       9994 non-null   str
#  2   Order Date     4042 non-null   datetime64[us]
#  3   Ship Date      3898 non-null   datetime64[us]
#  4   Ship Mode      9994 non-null   str
#  5   Customer ID    9994 non-null   str
#  6   Customer Name  9994 non-null   str
#  7   Segment        9994 non-null   str
#  8   Country        9994 non-null   str
#  9   City           9994 non-null   str
#  10  State          9994 non-null   str
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   str
#  13  Product ID     9994 non-null   str
#  14  Category       9994 non-null   str
#  15  Sub-Category   9994 non-null   str
#  16  Product Name   9994 non-null   str
#  17  Sales          9994 non-null   float64
# ...

# %%
data.head()
# Out:
#    ï»¿Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12        NaT    Second Class
# 3          4  US-2015-108966 2015-10-11        NaT  Standard Class
# 4          5  US-2015-108966 2015-10-11        NaT  Standard Class
#
#   Customer ID    Customer Name    Segment        Country             City  \
# 0    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1    CG-12520      Claire Gute   Consumer  United States        Henderson
# 2    DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#    ... Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
data['Order Month']=data['Order Date'].dt.month
data['Order Year']=data['Order Date'].dt.year
data['Order Day of Week']=data['Order Date'].dt.dayofweek

# %%
data.head()
# Out:
#    ï»¿Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12        NaT    Second Class
# 3          4  US-2015-108966 2015-10-11        NaT  Standard Class
# 4          5  US-2015-108966 2015-10-11        NaT  Standard Class
#
#   Customer ID    Customer Name    Segment        Country             City  \
# 0    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1    CG-12520      Claire Gute   Consumer  United States        Henderson
# 2    DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#    ...         Category  Sub-Category  \
# 0  ...        Furniture     Bookcases
# ...

# %% [markdown]
# # Monthly Sales Analysis

# %%
Sales_by_month = data.groupby('Order Month')['Sales'].sum().reset_index()
fig=px.line(Sales_by_month,
            x='Order Month',
            y='Sales',
            title='Monthly Sales Analysis')
fig.show()

# %% [markdown]
# # Lowest monthly sales - 1(january) and highest monthly sales - 11 (november)

# %%
Sales_by_month = data.groupby('Order Month')['Sales'].sum().reset_index()
sales_by_month
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 Sales_by_month = data.groupby('Order Month')['Sales'].sum().reset_index()
# ----> 2 sales_by_month
#
# NameError: name 'sales_by_month' is not defined

# %% [markdown]
# # Sales analysis by category

# %%
data.head()

# %%
Sales_by_category=data.groupby('Category')['Sales'].sum().reset_index()
Sales_by_category

# %%
Sales_by_category=data.groupby('Category')['Sales'].sum().reset_index()
fig=px.line(Sales_by_category,
            x='Category',
            y='Sales',
            title='CATEGORY WISE SALES ANALYSIS')
fig.show()

# %% [markdown]
# # Lowest sales of category - Office Supplies and highest sales of category - Technology

# %%
fig= px.pie(Sales_by_category,
            values='Sales',
            names='Category',
            hole=0.5,
            color_discrete_sequence=px.colors.qualitative.Pastel)
fig.update_traces(textposition='inside', textinfo='percent+label')
fig.update_layout(title_text='Sales Analysis by Category' , title_font=dict(size=24) )

fig.show()

# %% [markdown]
# # Sales analysis by sub-category

# %%
data.head()

# %%
Sales_by_subcategory=data.groupby('Sub-Category')['Sales'].sum().reset_index()
Sales_by_subcategory

# %%
fig=px.line(Sales_by_subcategory,
            x='Sub-Category',
            y='Sales',
            title='Sales analysis by subcategory')
fig.show()

# %%
fig=px.bar(Sales_by_subcategory,
           x='Sub-Category',
           y='Sales',
           title='Sales analysis by subcategory using bar graph')
fig.show()

# %% [markdown]
# # highest sales = chairs and lowest sales = fasteners

# %% [markdown]
# # Sales and profit - customer segment

# %%
Sales_profit_by_segment=data.groupby('Segment').agg({'Sales':'sum','Profit':'sum'}).reset_index()
color_palette=colors.qualitative.Pastel

fig=go.Figure()
fig.add_trace(go.Bar(x = Sales_profit_by_segment['Segment'],
                     y= Sales_profit_by_segment['Sales'],
                     name='Sales',
                     marker_color=color_palette[0]))
fig.add_trace(go.Bar(x=Sales_profit_by_segment['Segment'],
                     y=Sales_profit_by_segment['Profit'],
                     name='Profit',
                     marker_color=color_palette[1]))
fig.update_layout(title='Sales and Profit Analysis by Customer Segment',
                  xaxis_title='Customer Segment',
                  yaxis_title='Amount')
fig.show()

# %% [markdown]
# # Sales to Profit ratio

# %%
Sales_profit_by_segment=data.groupby('Segment').agg({'Sales':'sum','Profit':'sum'}).reset_index()
Sales_profit_by_segment['Sales_to_Profit_ratio']=Sales_profit_by_segment['Sales']/Sales_profit_by_segment['Profit']
print(Sales_profit_by_segment[['Segment','Sales_to_Profit_ratio']])
# Out:
#        Segment  Sales_to_Profit_ratio
# 0     Consumer               8.659471
# 1    Corporate               7.677245
# 2  Home Office               7.125416
